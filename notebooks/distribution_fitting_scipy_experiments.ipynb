# %%
import pandas as pd
import fitter


l1_start_times = pd.read_csv('../data/L1_start_times.csv')
l2_start_times = pd.read_csv('../data/L2_start_times.csv')
l1_durations = pd.read_csv('../data/l1_durations_xformed.csv')
l2_durations = pd.read_csv('../data/l2_durations_xformed.csv')

# %%
f = fitter.Fitter(l1_durations,bins=60)
f.fit()
# may take some time since by default, all distributions are tried
# but you call manually provide a smaller set of distributions
f.summary()
# Out:
# ...
# Fitting 109 distributions:   1%|          | 1/109 [00:01<01:51,  1.03s/it]WARNING:root:SKIPPED foldnorm distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED gamma distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# Fitting 109 distributions:   2%|▏         | 2/109 [00:31<32:15, 18.09s/it]WARNING:root:SKIPPED anglit distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED arcsine distribution (taking more than 30 seconds)
# Fitting 109 distributions:   4%|▎         | 4/109 [00:31<10:38,  6.08s/it]WARNING:root:SKIPPED argus distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# Fitting 109 distributions:   5%|▍         | 5/109 [00:31<06:55,  4.00s/it]WARNING:root:SKIPPED beta distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED burr distribution (taking more than 30 seconds)
# ...

# %%
f.summary()
# Out:
#              sumsquare_error          aic           bic  kl_div  ks_statistic  \
# alpha               0.000047  1697.835340 -4.794801e+06     inf      0.076783
# dweibull            0.000076  1949.805330 -4.689008e+06     inf      0.304481
# pareto              0.000085  1710.414162 -4.665519e+06     inf      0.101658
# erlang              0.000126  1788.096837 -4.582191e+06     inf      0.109208
# fatiguelife         0.000132  1702.993330 -4.571225e+06     inf      0.106199
#
#              ks_pvalue
# alpha              0.0
# dweibull           0.0
# pareto             0.0
# erlang             0.0
# fatiguelife        0.0
# Error in callback <function flush_figures at 0x000001C6021A18B0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
# ...

# %%
import scipy.stats as stats
x = stats.pareto.fit(l1_durations)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
rv = stats.planck(lambda_)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()
