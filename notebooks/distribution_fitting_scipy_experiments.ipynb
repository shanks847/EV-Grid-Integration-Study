# %%
import pandas as pd
import fitter


# l1_start_times = pd.read_csv('../data/L1_start_times.csv')
# l2_start_times = pd.read_csv('../data/L2_start_times.csv')
# l1_durations = pd.read_csv('../data/l1_durations_xformed.csv')
# l2_durations = pd.read_csv('../data/l2_durations_xformed.csv')

l1_st_truns = pd.read_csv('../data/lev1_start_times_trunc.csv')

# %%
f = fitter.Fitter(l1_st_truns)
f.fit()
# may take some time since by default, all distributions are tried
# but you call manually provide a smaller set of distributions
f.summary()
# Out:
# ...
# Fitting 109 distributions:   7%|▋         | 8/109 [00:24<04:08,  2.46s/it]WARNING:root:SKIPPED alpha distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED betaprime distribution (taking more than 30 seconds)
# ...
# Fitting 109 distributions:  26%|██▌       | 28/109 [01:30<06:16,  4.64s/it]WARNING:root:SKIPPED gausshyper distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED genexpon distribution (taking more than 30 seconds)
# ...
# Fitting 109 distributions:  73%|███████▎  | 80/109 [04:20<01:21,  2.80s/it]WARNING:root:SKIPPED pearson3 distribution (taking more than 30 seconds)
# WARNING:root:SKIPPED rv_continuous distribution (taking more than 30 seconds)
# ...
# Fitting 109 distributions:  91%|█████████ | 99/109 [05:20<00:24,  2.45s/it]c:\Users\Shankar Ramharack\AppData\Local\Programs\Python\Python310\lib\site-packages\scipy\integrate\_quadpack_py.py:1151: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
# ...

# %%
import scipy.stats as stats

# %%
x = stats.weibull_max(l1_st_truns)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1, 1)

# %%
rv = stats.planck(lambda_)
ax.vlines(x, 0, rv.pmf(x), colors='k', linestyles='-', lw=1,
          label='frozen pmf')
ax.legend(loc='best', frameon=False)
plt.show()
